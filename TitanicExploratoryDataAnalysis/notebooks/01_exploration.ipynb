# %% [markdown]
# # Titanic EDA
# Goal: Initial data exploration and visualizations for the Titanic dataset

# %% [markdown]
# ### 1. Loading data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import importlib

from src import (
    load_data, show_info, refactor, remove_column,
    create_histplot, create_barplot, create_boxplot,
    create_heatmap, create_countplot)

# %%
titanic_df = load_data("../data/Titanic-Dataset.csv")

# %% [markdown]
# ### 2. Preprocessing Data

# %%
titanic_df = refactor(titanic_df)
show_info(titanic_df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    int64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        891 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 83.7+ KB
# --DataFrame Info--
#  None
# --Statistic--
#         PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# ...

# %% [markdown]
# ### 3. Visualization

# %% [markdown]
# #### 3.1 Creating a histplot

# %%
create_histplot(titanic_df, "Age")

# %% [markdown]
# #### 3.2 Creating a Barplot

# %%
create_barplot(titanic_df,["Sex","Pclass"])

# %% [markdown]
# #### 3.3 Creating a Boxplot

# %%
create_boxplot(titanic_df, ["Pclass", "Age"])

# %% [markdown]
# #### 3.4 Creating a Countplot

# %%
create_countplot(titanic_df, "Pclass")

# %% [markdown]
# ### 4. Correlationmatrix

# %%
create_heatmap(titanic_df)
